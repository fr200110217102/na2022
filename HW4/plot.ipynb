# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file = pd.read_csv("A.csv")

data = pd.DataFrame(file)
plt.plot(data['x'], data['f'])
plt.plot(data['x'], data['g'])
plt.plot(data['x'], data['h'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [-3.5,-3,-2.5,-2,-1.75,-1.5,-1.25,-1,-0.875,-0.75,-0.625,-0.5,0,0.5,0.625,0.75,0.875,1,1.25,1.5,1.75,2,2.5,3,3.5]
y = np.zeros_like(x)
plt.plot(x, y)
plt.scatter(x, y)

x = [-0.375,-0.25,-0.125,0,-0,0.125,0.25,0.375]
y = np.zeros_like(x)
plt.scatter(x, y)
