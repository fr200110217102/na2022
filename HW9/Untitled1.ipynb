# %%
import matplotlib.pyplot as plt

N_values = [6, 9, 12, 15, 18, 21, 24]
X_values = [77.5268, 64.9084, 42.138, 32.2899, 27.4135, 27.3815, 26.1786]
Y_values = [136.833, 133.073, 118.948, 127.908, 127.054, 122.622, 115.407]
Z_values = [0.286, 0, 0.806, 0.806, 0.806, 0.806, 0.806]
value_values = [221.509, 197.982, 181.236, 180.348, 174.618, 170.153, 161.735]

plt.figure(figsize=(10, 6))
plt.xlabel('N')
plt.ylabel('X')
plt.plot(N_values, X_values, label='X')
plt.legend()
plt.grid(True)
plt.show()
plt.xlabel('N')
plt.ylabel('Y')
plt.plot(N_values, Y_values, label='Y')
plt.legend()
plt.grid(True)
plt.show()
plt.xlabel('N')
plt.ylabel('Z')
plt.plot(N_values, Z_values, label='Z')
plt.legend()
plt.grid(True)
plt.show()
plt.xlabel('N')
plt.ylabel('value')
plt.plot(N_values, value_values, label='value')
plt.legend()
plt.grid(True)
plt.show()
