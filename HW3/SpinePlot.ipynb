# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a1.csv")
file2 = pd.read_csv("a2.csv")
file3 = pd.read_csv("a3.csv")
file4 = pd.read_csv("a4.csv")
file5 = pd.read_csv("a5.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a6.csv")
file2 = pd.read_csv("a7.csv")
file3 = pd.read_csv("a8.csv")
file4 = pd.read_csv("a9.csv")
file5 = pd.read_csv("a10.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a11.csv")
file2 = pd.read_csv("a12.csv")
file3 = pd.read_csv("a13.csv")
file4 = pd.read_csv("a14.csv")
file5 = pd.read_csv("a15.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a16.csv")
file2 = pd.read_csv("a17.csv")
file3 = pd.read_csv("a18.csv")
file4 = pd.read_csv("a19.csv")
file5 = pd.read_csv("a20.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + x**2)

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("cl.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])

plt.show()

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file2 = pd.read_csv("c1.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])

plt.show()

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file3 = pd.read_csv("c2.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])

plt.show()

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file4 = pd.read_csv("c3.csv")
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])

plt.show()

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file5 = pd.read_csv("cq.csv")
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file1 = pd.read_csv("e1.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
file2 = pd.read_csv("e2.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
file3 = pd.read_csv("e3.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file1 = pd.read_csv("e4.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
file2 = pd.read_csv("e5.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
file3 = pd.read_csv("e6.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file1 = pd.read_csv("e7.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
file2 = pd.read_csv("e8.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
file3 = pd.read_csv("e9.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
