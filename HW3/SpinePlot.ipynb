# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a1.csv")
file2 = pd.read_csv("a2.csv")
file3 = pd.read_csv("a3.csv")
file4 = pd.read_csv("a4.csv")
file5 = pd.read_csv("a5.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a6.csv")
file2 = pd.read_csv("a7.csv")
file3 = pd.read_csv("a8.csv")
file4 = pd.read_csv("a9.csv")
file5 = pd.read_csv("a10.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a11.csv")
file2 = pd.read_csv("a12.csv")
file3 = pd.read_csv("a13.csv")
file4 = pd.read_csv("a14.csv")
file5 = pd.read_csv("a15.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + 25*x**2)

x = np.linspace(-1, 1, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file1 = pd.read_csv("a16.csv")
file2 = pd.read_csv("a17.csv")
file3 = pd.read_csv("a18.csv")
file4 = pd.read_csv("a19.csv")
file5 = pd.read_csv("a20.csv")

data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file4)
plt.plot(data['x'], data['y'])
data = pd.DataFrame(file5)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def f(x) :
    return 1 / (1 + x**2)

x = np.linspace(-5, 5, 1000)
y = [f(t) for t in x]
plt.plot(x, y, '--')

file6 = pd.read_csv("b1.csv")
data = pd.DataFrame(file6)
plt.plot(data['x'], data['y'])

file7 = pd.read_csv("b2.csv")
data = pd.DataFrame(file7)
plt.plot(data['x'], data['y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file8 = pd.read_csv("e1.csv")
data = pd.DataFrame(file8)
plt.plot(data['x'], data['y'])
plt.show()
file9 = pd.read_csv("e2.csv")
data = pd.DataFrame(file9)
plt.plot(data['x'], data['y'])
plt.show()
file10 = pd.read_csv("e3.csv")
data = pd.DataFrame(file10)
plt.plot(data['x'], data['y'])
plt.show()
