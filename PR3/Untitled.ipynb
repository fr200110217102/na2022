# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from math import pi

# %%
file1 = pd.read_csv("01.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
plt.show()
file2 = pd.read_csv("02.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
plt.show()
file3 = pd.read_csv("03.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
plt.show()

# %%
file1 = pd.read_csv("11.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
plt.show()
file2 = pd.read_csv("12.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
plt.show()
file3 = pd.read_csv("13.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
plt.show()

# %%
file1 = pd.read_csv("21.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
plt.show()
file2 = pd.read_csv("22.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
plt.show()
file3 = pd.read_csv("23.csv")
data = pd.DataFrame(file3)
plt.plot(data['x'], data['y'])
plt.show()

# %%
file1 = pd.read_csv("31.csv")
data = pd.DataFrame(file1)
plt.plot(data['x'], data['y'])
plt.show()
file2 = pd.read_csv("32.csv")
data = pd.DataFrame(file2)
plt.plot(data['x'], data['y'])
plt.show()
